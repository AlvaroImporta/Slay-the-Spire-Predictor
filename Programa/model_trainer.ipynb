# %%
import pandas as pd
from sklearn.preprocessing import MaxAbsScaler
from sklearn.ensemble import ExtraTreesRegressor
import joblib

# %%
dict_characters = {'ironclad': 'DataSet_DummiesIC', 'silent': 'DataSet_DummiesTS', 'defect': 'DataSet_DummiesDF', 'watcher': 'DataSet_DummiesTS'}

for i in dict_characters:
    
    df = pd.read_csv('../Machine_learning/Load_data/'+ dict_characters[i] +'.csv')
    X = df.drop(columns=["level_asc_floor",'character', 'damage_taken','enemies','dmg_mean_ascension','enemy_type'])
    y = df["level_asc_floor"]

    scaler = MaxAbsScaler()
    X_scaled = scaler.fit_transform(X)

    model = ExtraTreesRegressor(n_estimators=100, random_state=42)
    model.fit(X_scaled, y)

    joblib.dump(model, 'extra_trees_'+ i +'.pkl')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 13
#      10 X_scaled = scaler.fit_transform(X)
#      12 model = ExtraTreesRegressor(n_estimators=100, random_state=42)
# ---> 13 model.fit(X_scaled, y)
#      15 joblib.dump(model, 'extra_trees_'+ i +'.pkl')
#
# File c:\Users\zubi_\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
# ...
